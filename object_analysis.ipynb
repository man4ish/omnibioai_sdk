# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# OmniBioAI Object Analysis\n",
        "\n",
        "This notebook was generated by OmniBioAI Workbench."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "import os\n",
        "from omnibioai_sdk import OmniClient\n",
        "\n",
        "# Filled by OmniBioAI when the notebook is generated\n",
        "OBJECT_ID = \"__OBJECT_ID__\"\n",
        "\n",
        "BASE_URL = os.getenv(\"OMNIBIOAI_BASE_URL\", \"http://127.0.0.1:8001\")\n",
        "TOKEN = os.getenv(\"OMNIBIOAI_TOKEN\", \"dev\")\n",
        "\n",
        "c = OmniClient(base_url=BASE_URL, token=TOKEN)\n",
        "obj = c.object_get(OBJECT_ID)\n",
        "obj[\"object_type\"], obj.get(\"metadata\", {})\n"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {},
      "outputs": [],
      "source": [
        "# Explore registry\n",
        "lst = c.objects_list()\n",
        "lst[\"count\"], lst[\"items\"][0]\n"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python (omnibioai-base)",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
